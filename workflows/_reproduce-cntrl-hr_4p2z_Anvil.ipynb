# %% [markdown]
# # Demonstrate Reproducible Control Integration

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import cesm
import config
import atlas
# Out:
# /home/x-mlong/.local/share/mamba/envs/cesm2.2.0/lib/python3.11/site-packages/pop_tools/__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %%
blueprint = "hr_4p2z"
project = config.project_sname
simulation_name = "control"
vintage = "001"

case = f"{blueprint}.{project}.{simulation_name}.{vintage}"
case
# Out:
# 'hr_4p2z.cdr-atlas-v0.control.001'

# %%
cesm.create_hr_4p2z_clone(
    case,
    cdr_forcing=None,
    refdate="1999-01-01",
    stop_n=1,
    stop_option="nday",    
    queue="wholenode",
    clobber=True,
)
# Out:
# Compset longname is 1850_DATM%JRA-1p4-2018_SLND_CICE%CICE4_POP2%ECO_DROF%JRA-1p4-2018_SGLC_SWAV
# Compset specification file is /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/codes/cesm2.2.0/components/pop//cime_config/config_compsets.xml
# Automatically adding SIAC to compset
# Automatically adding SESP to compset
# Compset forcing is 1850
# Warning: missing non-idmap ROF2OCN_FMAPNAME for rof_grid, JRA025v2 and ocn_grid tx0.1v3
# ATM component is  Data driven ATM interannual JRA55 forcing, v1.4, through 2018
# LND component is Stub land component
# ICE component is Sea ICE (cice) model version 5 :running with cice4 physics
# OCN component is POP2 Ecosystem
# ROF component is Data runoff modelJRA55 interannual forcing, v1.4, through 2018
# GLC component is Stub glacier (land ice) component
# WAV component is Stub wave component
# IAC component is Stub iac component
# ESP component is Stub external system processing (ESP) component
# Pes     specification file is /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/codes/cesm2.2.0/components/pop//cime_config/config_pes.xml
# Could not find machine match for 'a241.anvil.rcac.purdue.edu' or 'a241.anvil.rcac.purdue.edu'
# WARNING: No cesm Model version found.
# Machine is anvil
# Pes setting: grid match    is oi%tx0.1v3
# Pes setting: compset_match is _DATM.*_CICE.*_POP2
# Pes setting: grid          is a%TL319_l%null_oi%tx0.1v3_r%JRA025v2_g%null_w%null_z%null_m%tx0.1v3
# Pes setting: compset       is 1850_DATM%JRA-1p4-2018_SLND_CICE%CICE4_POP2%ECO_DROF%JRA-1p4-2018_SGLC_SWAV_SIAC_SESP
# Pes setting: tasks       is {'NTASKS_ATM': 48, 'NTASKS_LND': 48, 'NTASKS_ROF': 48, 'NTASKS_ICE': 828, 'NTASKS_OCN': 2208, 'NTASKS_GLC': 48, 'NTASKS_WAV': 48, 'NTASKS_CPL': 828}
# Pes setting: threads     is {'NTHRDS_ATM': 1, 'NTHRDS_LND': 1, 'NTHRDS_ROF': 1, 'NTHRDS_ICE': 1, 'NTHRDS_OCN': 1, 'NTHRDS_GLC': 1, 'NTHRDS_WAV': 1, 'NTHRDS_CPL': 1}
# Pes setting: rootpe      is {'ROOTPE_ATM': 0, 'ROOTPE_LND': 0, 'ROOTPE_ROF': 0, 'ROOTPE_ICE': 0, 'ROOTPE_OCN': 828, 'ROOTPE_GLC': 0, 'ROOTPE_WAV': 0, 'ROOTPE_CPL': 0}
# Pes setting: pstrid      is {}
# Pes other settings: {}
# Pes comments: none
#  Compset is: 1850_DATM%JRA-1p4-2018_SLND_CICE%CICE4_POP2%ECO_DROF%JRA-1p4-2018_SGLC_SWAV_SIAC_SESP
#  Grid is: a%TL319_l%null_oi%tx0.1v3_r%JRA025v2_g%null_w%null_z%null_m%tx0.1v3
#  Components in compset are: ['datm', 'slnd', 'cice', 'pop', 'drof', 'sglc', 'swav', 'siac', 'sesp']
# No charge_account info available, using value from PROJECT
# Batch_system_type is slurm
# job is case.run USER_REQUESTED_WALLTIME 48:00:00 USER_REQUESTED_QUEUE wholenode WALLTIME_FORMAT %H:%M:%S
# job is case.st_archive USER_REQUESTED_WALLTIME None USER_REQUESTED_QUEUE None WALLTIME_FORMAT %H:%M:%S
#  Creating Case directory /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001
# Setting Environment MPICH_ENV_DISPLAY=1
# Setting Environment MPICH_VERSION_DISPLAY=1
# Setting Environment OMP_STACKSIZE=128M
# Setting Environment OMP_PROC_BIND=spread
# Setting Environment OMP_PLACES=threads
# Setting Environment HDF5_USE_FILE_LOCKING=FALSE
# Setting Environment PERL5LIB=/anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/perl5-only-switch
# Setting Environment FI_CXI_RX_MATCH_MODE=software
# Setting Environment MPICH_COLL_SYNC=MPI_Bcast
# Setting Environment NETCDF_PATH=/apps/spack/anvil/apps/netcdf-c/4.7.4-intel-19.0.5-s4yiaxl
# Setting Environment PNETCDF_PATH=/apps/spack/anvil/apps/parallel-netcdf/1.11.2-intel-19.0.5-przs3qa
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# job is case.run USER_REQUESTED_WALLTIME 48:00:00 USER_REQUESTED_QUEUE wholenode WALLTIME_FORMAT %H:%M:%S
# Creating batch scripts
# Writing case.run script from input template /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/codes/cesm2.2.0/cime/config/cesm/machines/template.case.run
# /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/env_mach_specific.xml already exists, delete to replace
# /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/env_mach_specific.xml already exists, delete to replace
# Creating file .case.run
# Writing case.st_archive script from input template /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/codes/cesm2.2.0/cime/config/cesm/machines/template.st_archive
# Creating file case.st_archive
# Creating user_nl_xxx files for components and cpl
# If an old case build already exists, might want to run 'case.build --clean' before building
# You can now run './preview_run' to get more info on how your case will be run
# /home/x-mlong/codes/Ocean-CDR-Atlas-v0/workflows/input/cesm2.2.0/cases/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001/user_nl_drof -> /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/user_nl_drof
# /home/x-mlong/codes/Ocean-CDR-Atlas-v0/workflows/input/cesm2.2.0/cases/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001/user_nl_pop -> /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/user_nl_pop
# /home/x-mlong/codes/Ocean-CDR-Atlas-v0/workflows/input/cesm2.2.0/cases/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001/user_nl_cice -> /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/user_nl_cice
# /home/x-mlong/codes/Ocean-CDR-Atlas-v0/workflows/input/cesm2.2.0/cases/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001/user_nl_datm -> /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/user_nl_datm
# /home/x-mlong/codes/Ocean-CDR-Atlas-v0/workflows/input/cesm2.2.0/cases/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001/user_nl_marbl -> /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/user_nl_marbl
# /home/x-mlong/codes/Ocean-CDR-Atlas-v0/workflows/input/cesm2.2.0/cases/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001/user_datm.streams.txt.co2tseries.omip -> /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/user_datm.streams.txt.co2tseries.omip
# /home/x-mlong/codes/Ocean-CDR-Atlas-v0/workflows/input/cesm2.2.0/cases/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001/user_datm.streams.txt.CORE_IAF_JRA.NCEP.V_10 -> /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/user_datm.streams.txt.CORE_IAF_JRA.NCEP.V_10
# /home/x-mlong/codes/Ocean-CDR-Atlas-v0/workflows/input/cesm2.2.0/cases/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001/user_datm.streams.txt.CORE_IAF_JRA.NCEP.SLP_ -> /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/user_datm.streams.txt.CORE_IAF_JRA.NCEP.SLP_
# /home/x-mlong/codes/Ocean-CDR-Atlas-v0/workflows/input/cesm2.2.0/cases/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001/user_datm.streams.txt.CORE_IAF_JRA.NCEP.T_10 -> /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/user_datm.streams.txt.CORE_IAF_JRA.NCEP.T_10
# /home/x-mlong/codes/Ocean-CDR-Atlas-v0/workflows/input/cesm2.2.0/cases/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001/user_datm.streams.txt.CORE_IAF_JRA.GISS.LWDN -> /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/user_datm.streams.txt.CORE_IAF_JRA.GISS.LWDN
# /home/x-mlong/codes/Ocean-CDR-Atlas-v0/workflows/input/cesm2.2.0/cases/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001/user_datm.streams.txt.presaero.clim_1850 -> /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/user_datm.streams.txt.presaero.clim_1850
# /home/x-mlong/codes/Ocean-CDR-Atlas-v0/workflows/input/cesm2.2.0/cases/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001/user_datm.streams.txt.CORE_IAF_JRA.NCEP.U_10 -> /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/user_datm.streams.txt.CORE_IAF_JRA.NCEP.U_10
# /home/x-mlong/codes/Ocean-CDR-Atlas-v0/workflows/input/cesm2.2.0/cases/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001/user_datm.streams.txt.CORE_IAF_JRA.GCGCS.PREC -> /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/user_datm.streams.txt.CORE_IAF_JRA.GCGCS.PREC
# /home/x-mlong/codes/Ocean-CDR-Atlas-v0/workflows/input/cesm2.2.0/cases/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001/user_datm.streams.txt.CORE_IAF_JRA.NCEP.Q_10 -> /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/user_datm.streams.txt.CORE_IAF_JRA.NCEP.Q_10
# /home/x-mlong/codes/Ocean-CDR-Atlas-v0/workflows/input/cesm2.2.0/cases/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001/user_datm.streams.txt.CORE_IAF_JRA.GISS.SWDN -> /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/user_datm.streams.txt.CORE_IAF_JRA.GISS.SWDN
# '/anvil/projects/x-ees250129/Datasets/HR_4p2z/rest/1999-01-01-00000/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001.cice.r.1999-01-01-00000.nc' -> '/anvil/scratch/x-mlong/Ocean-CDR-Atlas-v0/hr_4p2z.cdr-atlas-v0.control.001/run/./g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001.cice.r.1999-01-01-00000.nc'
# '/anvil/projects/x-ees250129/Datasets/HR_4p2z/rest/1999-01-01-00000/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001.cpl.r.1999-01-01-00000.nc' -> '/anvil/scratch/x-mlong/Ocean-CDR-Atlas-v0/hr_4p2z.cdr-atlas-v0.control.001/run/./g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001.cpl.r.1999-01-01-00000.nc'
# '/anvil/projects/x-ees250129/Datasets/HR_4p2z/rest/1999-01-01-00000/g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001.pop.r.1999-01-01-00000.nc' -> '/anvil/scratch/x-mlong/Ocean-CDR-Atlas-v0/hr_4p2z.cdr-atlas-v0.control.001/run/./g.e22.TL319_t13.G1850ECOIAF_JRA_HR.4p2z.001.pop.r.1999-01-01-00000.nc'
# '/anvil/projects/x-ees250129/Datasets/HR_4p2z/rest/1999-01-01-00000/rpointer.atm' -> '/anvil/scratch/x-mlong/Ocean-CDR-Atlas-v0/hr_4p2z.cdr-atlas-v0.control.001/run/./rpointer.atm'
# '/anvil/projects/x-ees250129/Datasets/HR_4p2z/rest/1999-01-01-00000/rpointer.drv' -> '/anvil/scratch/x-mlong/Ocean-CDR-Atlas-v0/hr_4p2z.cdr-atlas-v0.control.001/run/./rpointer.drv'
# '/anvil/projects/x-ees250129/Datasets/HR_4p2z/rest/1999-01-01-00000/rpointer.ice' -> '/anvil/scratch/x-mlong/Ocean-CDR-Atlas-v0/hr_4p2z.cdr-atlas-v0.control.001/run/./rpointer.ice'
# '/anvil/projects/x-ees250129/Datasets/HR_4p2z/rest/1999-01-01-00000/rpointer.ocn.ovf' -> '/anvil/scratch/x-mlong/Ocean-CDR-Atlas-v0/hr_4p2z.cdr-atlas-v0.control.001/run/./rpointer.ocn.ovf'
# '/anvil/projects/x-ees250129/Datasets/HR_4p2z/rest/1999-01-01-00000/rpointer.ocn.restart' -> '/anvil/scratch/x-mlong/Ocean-CDR-Atlas-v0/hr_4p2z.cdr-atlas-v0.control.001/run/./rpointer.ocn.restart'
# '/anvil/projects/x-ees250129/Datasets/HR_4p2z/rest/1999-01-01-00000/rpointer.ocn.tavg' -> '/anvil/scratch/x-mlong/Ocean-CDR-Atlas-v0/hr_4p2z.cdr-atlas-v0.control.001/run/./rpointer.ocn.tavg'
# '/anvil/projects/x-ees250129/Datasets/HR_4p2z/rest/1999-01-01-00000/rpointer.rof' -> '/anvil/scratch/x-mlong/Ocean-CDR-Atlas-v0/hr_4p2z.cdr-atlas-v0.control.001/run/./rpointer.rof'
# Building case in directory /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001
# sharedlib_only is False
# model_only is False
# Setting Environment MPICH_ENV_DISPLAY=1
# Setting Environment MPICH_VERSION_DISPLAY=1
# Setting Environment OMP_STACKSIZE=128M
# Setting Environment OMP_PROC_BIND=spread
# Setting Environment OMP_PLACES=threads
# Setting Environment HDF5_USE_FILE_LOCKING=FALSE
# Setting Environment PERL5LIB=/anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/perl5-only-switch
# Setting Environment FI_CXI_RX_MATCH_MODE=software
# Setting Environment MPICH_COLL_SYNC=MPI_Bcast
# Setting Environment NETCDF_PATH=/apps/spack/anvil/apps/netcdf-c/4.7.4-intel-19.0.5-s4yiaxl
# Setting Environment PNETCDF_PATH=/apps/spack/anvil/apps/parallel-netcdf/1.11.2-intel-19.0.5-przs3qa
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Generating component namelists as part of build
# GET_REFCASE is false, the user is expected to stage the refcase to the run directory.
# Creating component namelists
#   2026-01-28 12:12:10 atm
#    Calling /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/codes/cesm2.2.0/cime/src/components/data_comps_mct/datm/cime_config/buildnml
#   2026-01-28 12:12:11 lnd
#    Calling /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/codes/cesm2.2.0/cime/src/components/stub_comps_mct/slnd/cime_config/buildnml
#   2026-01-28 12:12:11 ice
#    Calling /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/codes/cesm2.2.0/components/cice//cime_config/buildnml
#      ...buildnml calling cice buildcpp to set build time options
#   2026-01-28 12:12:11 ocn
#    Calling /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/codes/cesm2.2.0/components/pop//cime_config/buildnml
#      ... buildnml: calling pop buildcpp to set build time options
# ERROR: Command /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/codes/cesm2.2.0/components/pop/bld/build-namelist failed rc=1
# out=
# err=Traceback (most recent call last):
#   File "/anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/./xmlquery", line 100, in <module>
#     from standard_script_setup import *
#   File "/anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/codes/cesm2.2.0/cime/scripts/Tools/standard_script_setup.py", line 16, in <module>
#     import CIME.utils
#   File "/anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/codes/cesm2.2.0/cime/scripts/Tools/../../scripts/lib/CIME/utils.py", line 5, in <module>
#     import io, logging, gzip, sys, os, time, re, shutil, glob, string, random, imp, fnmatch
# ModuleNotFoundError: No module named 'imp'
# Traceback (most recent call last):
#   File "/anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001/./xmlchange", line 49, in <module>
#     from standard_script_setup import *
#   File "/anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/codes/cesm2.2.0/cime/scripts/Tools/standard_script_setup.py", line 16, in <module>
#     import CIME.utils
#   File "/anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/codes/cesm2.2.0/cime/scripts/Tools/../../scripts/lib/CIME/utils.py", line 5, in <module>
#     import io, logging, gzip, sys, os, time, re, shutil, glob, string, random, imp, fnmatch
# ModuleNotFoundError: No module named 'imp'
# ERROR: cd /anvil/projects/x-ees250129/Ocean-CDR-Atlas-v0/cases/hr_4p2z.cdr-atlas-v0.control.001 ; ./xmlchange --noecho CPL_I2O_PER_CAT=TRUE failed: 256
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cesm.create_hr_4p2z_clone(
#       2     case,
#       3     cdr_forcing=None,
#       4     refdate="1999-01-01",
#       5     stop_n=1,
#       6     stop_option="nday",
#       7     queue="wholenode",
#       8     clobber=True,
#       9 )
#
# File ~/codes/Ocean-CDR-Atlas-v0/workflows/cesm.py:506, in create_hr_4p2z_clone(case, refdate, queue, cdr_forcing, cdr_forcing_file, clobber, curtail_output, stop_n, stop_option, wallclock, resubmit)
#     500 # copy restarts
#     501 check_call(
#     502     f"cp -v {refcaserest_root}/{refdate}-00000/* {rundir}/.",
#     503     shell=True,
#     504 )
# --> 506 check_call(
#     507     "module load python && ./case.build --skip-provenance-check",
#     508     cwd=caseroot,
#     509     shell=True,
#     510 )
#
# File ~/.local/share/mamba/envs/cesm2.2.0/lib/python3.11/subprocess.py:413, in check_call(*popenargs, **kwargs)
#     411     if cmd is None:
#     412         cmd = popenargs[0]
# --> 413     raise CalledProcessError(retcode, cmd)
#     414 return 0
#
# CalledProcessError: Command 'module load python && ./case.build --skip-provenance-check' returned non-zero exit status 1.

# %%
#atlas.submit_cases([case])
